# %% [markdown]
# # BioShake manual run notebook
#
# Run the cells top to bottom.
#
# If execution is interrupted while the shaker is running, execute the stop cell and then the cleanup cell before reconnecting.

# %%
import logging
import time

from bioshake_driver import BioShake

DEFAULT_PORT = "COM6"
TARGET_SPEED_RPM = 500
SHAKE_DURATION_SECONDS = 5

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s %(name)s: %(message)s",
)
logger = logging.getLogger("bioshake-notebook")

# %%
bioshake = BioShake(port=DEFAULT_PORT)
logger.info("Connected to shaker on %s", DEFAULT_PORT)
# Out:
# 2026-03-30 15:17:11,491 ERROR bioshake_driver.serial.BioShake.2568875236304: Failed to connect to COM6 at 9600 baud
# 2026-03-30 15:17:11,492 INFO bioshake-notebook: Connected to shaker on COM6

# %%
logger.info("Homing shaker on %s", DEFAULT_PORT)
bioshake.home()
# Out:
# 2026-03-30 15:17:13,065 INFO bioshake-notebook: Homing shaker on COM6

# %%
logger.info(
    "Shaking at %s RPM for %s seconds",
    TARGET_SPEED_RPM,
    SHAKE_DURATION_SECONDS,
)
bioshake.shake(500, SHAKE_DURATION_SECONDS)
# Out:
# 2026-03-30 15:17:19,229 INFO bioshake-notebook: Shaking at 500 RPM for 5 seconds
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 6
#       2     "Shaking at %s RPM for %s seconds",
#       3     TARGET_SPEED_RPM,
#       4     SHAKE_DURATION_SECONDS,
#       5 )
# ----> 6 bioshake.shake(500, SHAKE_DURATION_SECONDS)
#
# File ~\workspace\bioshake\driver\src\bioshake_driver\bioshake.py:547, in BioShake.shake(self, speed, duration)
#     544 if duration < 0:
#     545     raise ValueError("Duration must be greater than or equal to 0 seconds.")
# --> 547 min_speed = self._get_shake_min_rpm()
#     548 if min_speed is not None and speed < min_speed:
#     549     raise ValueError(
#     550         f"Target speed {speed} RPM is below the device minimum of {min_speed:.1f} RPM."
#     551     )
#
# File ~\workspace\bioshake\driver\src\bioshake_driver\bioshake.py:363, in BioShake._get_shake_min_rpm(self)
#     356 """
#     357 Returns the device specific minimum target speed (i.e. hardware limits)
#     358
#     359 Returns:
#     360     float|None: minimum target shake speed
#     361 """
#     362 out: FloatData = self._query("getShakeMinRpm", data_type=FloatData)
# --> 363 return out.data
#
# AttributeError: 'NoneType' object has no attribute 'data'

# %%
logger.info("Stopping shaker and returning home")
bioshake.home()
# Out:
# 2026-03-30 15:07:02,638 INFO bioshake-notebook: Stopping shaker and returning home
# 2026-03-30 15:07:02,773 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:02,903 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:03,028 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:03,156 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:03,284 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:03,411 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:03,540 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:03,667 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:03,811 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:03,939 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:04,067 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:04,195 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:04,322 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:04,452 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:04,594 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:04,722 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:04,850 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:04,978 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:05,105 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:05,233 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:05,361 INFO bioshake_driver.serial.BioShake.2568869424032: Detected a stop command
# 2026-03-30 15:07:05,744 INFO bioshake_driver.serial.BioShake.2568869424032: Stopped and is locked at home position
# 2026-03-30 15:07:05,778 INFO bioshake_driver.serial.BioShake.2568869424032: Stopped and is locked at home position

# %%
TARGET_TEMP_C = 60
TEMP_HOLD_SECONDS = 30

logger.info(
    "Heating to %d C and holding for %d seconds",
    TARGET_TEMP_C,
    TEMP_HOLD_SECONDS,
)
bioshake.set_temp(TARGET_TEMP_C, TEMP_HOLD_SECONDS)
# Out:
# 2026-03-30 15:07:12,301 INFO bioshake-notebook: Heating to 60 C and holding for 30 seconds
# 2026-03-30 15:07:12,359 INFO bioshake_driver.serial.BioShake.2568869424032: Setting target temperature to 60.0 C
# 2026-03-30 15:07:12,423 INFO bioshake_driver.serial.BioShake.2568869424032: Enabling temperature control
# 2026-03-30 15:07:12,471 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:12,474 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature is within 5.0 C of target; holding for 30 seconds
# 2026-03-30 15:07:13,014 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:13,557 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:14,101 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:14,644 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:15,187 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:15,730 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:16,273 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:16,816 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.7 C target=60.0 C
# 2026-03-30 15:07:17,362 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.7 C target=60.0 C
# 2026-03-30 15:07:17,903 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.7 C target=60.0 C
# 2026-03-30 15:07:18,446 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.7 C target=60.0 C
# 2026-03-30 15:07:18,989 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.6 C target=60.0 C
# 2026-03-30 15:07:19,533 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.6 C target=60.0 C
# 2026-03-30 15:07:20,076 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.7 C target=60.0 C
# 2026-03-30 15:07:20,619 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.7 C target=60.0 C
# 2026-03-30 15:07:21,162 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.8 C target=60.0 C
# 2026-03-30 15:07:21,706 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.8 C target=60.0 C
# 2026-03-30 15:07:22,249 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:22,792 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:23,335 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:23,878 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:24,422 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:24,965 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:25,508 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:26,052 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:26,595 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:27,138 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.8 C target=60.0 C
# 2026-03-30 15:07:27,682 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.8 C target=60.0 C
# 2026-03-30 15:07:28,225 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.7 C target=60.0 C
# 2026-03-30 15:07:28,768 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.7 C target=60.0 C
# 2026-03-30 15:07:29,311 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.7 C target=60.0 C
# 2026-03-30 15:07:29,855 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.7 C target=60.0 C
# 2026-03-30 15:07:30,398 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.7 C target=60.0 C
# 2026-03-30 15:07:30,941 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.7 C target=60.0 C
# 2026-03-30 15:07:31,485 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:32,027 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:32,570 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:33,113 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:33,657 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:34,200 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:34,743 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=60.0 C target=60.0 C
# 2026-03-30 15:07:35,286 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:35,829 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:36,373 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:36,916 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:37,459 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.8 C target=60.0 C
# 2026-03-30 15:07:38,003 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.8 C target=60.0 C
# 2026-03-30 15:07:38,546 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.8 C target=60.0 C
# 2026-03-30 15:07:39,089 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.8 C target=60.0 C
# 2026-03-30 15:07:39,633 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.8 C target=60.0 C
# 2026-03-30 15:07:40,176 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.8 C target=60.0 C
# 2026-03-30 15:07:40,719 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:41,262 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:41,805 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:42,348 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:42,891 INFO bioshake_driver.serial.BioShake.2568869424032: Temperature status: actual=59.9 C target=60.0 C
# 2026-03-30 15:07:42,892 INFO bioshake_driver.serial.BioShake.2568869424032: Disabling temperature control
# 2026-03-30 15:07:42,907 INFO bioshake_driver.serial.BioShake.2568869424032: Maintained target temperature 60.0 C for 30 seconds

# %%
bioshake.temp_off()

# %%
while True:
    actual_temp = bioshake.get_temp_actual()

    if actual_temp is None:
        raise RuntimeError("BioShake did not report an actual temperature")

    logger.info(
        "Temperature monitor: actual=%.1f C target=%.1f C",
        actual_temp,
        TARGET_TEMP_C,
    )
    time.sleep(0.5)
# Out:
# 2026-03-30 15:09:05,450 INFO bioshake-notebook: Temperature monitor: actual=52.3 C target=60.0 C
# 2026-03-30 15:09:05,993 INFO bioshake-notebook: Temperature monitor: actual=52.2 C target=60.0 C
# 2026-03-30 15:09:06,536 INFO bioshake-notebook: Temperature monitor: actual=52.2 C target=60.0 C
# 2026-03-30 15:09:07,080 INFO bioshake-notebook: Temperature monitor: actual=52.2 C target=60.0 C
# 2026-03-30 15:09:07,623 INFO bioshake-notebook: Temperature monitor: actual=52.2 C target=60.0 C
# 2026-03-30 15:09:08,166 INFO bioshake-notebook: Temperature monitor: actual=52.0 C target=60.0 C
# 2026-03-30 15:09:08,709 INFO bioshake-notebook: Temperature monitor: actual=52.0 C target=60.0 C
# 2026-03-30 15:09:09,253 INFO bioshake-notebook: Temperature monitor: actual=52.0 C target=60.0 C
# 2026-03-30 15:09:09,796 INFO bioshake-notebook: Temperature monitor: actual=51.9 C target=60.0 C
# 2026-03-30 15:09:10,339 INFO bioshake-notebook: Temperature monitor: actual=51.9 C target=60.0 C
# 2026-03-30 15:09:10,882 INFO bioshake-notebook: Temperature monitor: actual=51.9 C target=60.0 C
# 2026-03-30 15:09:11,426 INFO bioshake-notebook: Temperature monitor: actual=51.9 C target=60.0 C
# 2026-03-30 15:09:11,969 INFO bioshake-notebook: Temperature monitor: actual=51.8 C target=60.0 C
# 2026-03-30 15:09:12,512 INFO bioshake-notebook: Temperature monitor: actual=51.8 C target=60.0 C
# 2026-03-30 15:09:13,055 INFO bioshake-notebook: Temperature monitor: actual=51.7 C target=60.0 C
# 2026-03-30 15:09:13,598 INFO bioshake-notebook: Temperature monitor: actual=51.7 C target=60.0 C
# 2026-03-30 15:09:14,141 INFO bioshake-notebook: Temperature monitor: actual=51.7 C target=60.0 C
# 2026-03-30 15:09:14,685 INFO bioshake-notebook: Temperature monitor: actual=51.7 C target=60.0 C
# 2026-03-30 15:09:15,228 INFO bioshake-notebook: Temperature monitor: actual=51.6 C target=60.0 C
# 2026-03-30 15:09:15,787 INFO bioshake-notebook: Temperature monitor: actual=51.5 C target=60.0 C
# 2026-03-30 15:09:16,331 INFO bioshake-notebook: Temperature monitor: actual=51.5 C target=60.0 C
# 2026-03-30 15:09:16,874 INFO bioshake-notebook: Temperature monitor: actual=51.5 C target=60.0 C
# 2026-03-30 15:09:17,417 INFO bioshake-notebook: Temperature monitor: actual=51.5 C target=60.0 C
# 2026-03-30 15:09:17,960 INFO bioshake-notebook: Temperature monitor: actual=51.4 C target=60.0 C
# 2026-03-30 15:09:18,504 INFO bioshake-notebook: Temperature monitor: actual=51.4 C target=60.0 C
# 2026-03-30 15:09:19,082 INFO bioshake-notebook: Temperature monitor: actual=51.3 C target=60.0 C
# 2026-03-30 15:09:19,622 INFO bioshake-notebook: Temperature monitor: actual=51.3 C target=60.0 C
# 2026-03-30 15:09:20,165 INFO bioshake-notebook: Temperature monitor: actual=51.3 C target=60.0 C
# 2026-03-30 15:09:20,708 INFO bioshake-notebook: Temperature monitor: actual=51.3 C target=60.0 C
# 2026-03-30 15:09:21,252 INFO bioshake-notebook: Temperature monitor: actual=51.2 C target=60.0 C
# 2026-03-30 15:09:21,795 INFO bioshake-notebook: Temperature monitor: actual=51.2 C target=60.0 C
# 2026-03-30 15:09:22,338 INFO bioshake-notebook: Temperature monitor: actual=51.2 C target=60.0 C
# 2026-03-30 15:09:22,897 INFO bioshake-notebook: Temperature monitor: actual=51.1 C target=60.0 C
# 2026-03-30 15:09:23,441 INFO bioshake-notebook: Temperature monitor: actual=51.1 C target=60.0 C
# 2026-03-30 15:09:23,984 INFO bioshake-notebook: Temperature monitor: actual=51.0 C target=60.0 C
# 2026-03-30 15:09:24,527 INFO bioshake-notebook: Temperature monitor: actual=51.0 C target=60.0 C
# 2026-03-30 15:09:25,070 INFO bioshake-notebook: Temperature monitor: actual=51.0 C target=60.0 C
# 2026-03-30 15:09:25,613 INFO bioshake-notebook: Temperature monitor: actual=51.0 C target=60.0 C
# 2026-03-30 15:09:26,157 INFO bioshake-notebook: Temperature monitor: actual=50.9 C target=60.0 C
# 2026-03-30 15:09:26,700 INFO bioshake-notebook: Temperature monitor: actual=50.9 C target=60.0 C
# 2026-03-30 15:09:27,243 INFO bioshake-notebook: Temperature monitor: actual=50.9 C target=60.0 C
# 2026-03-30 15:09:27,787 INFO bioshake-notebook: Temperature monitor: actual=50.9 C target=60.0 C
# 2026-03-30 15:09:28,330 INFO bioshake-notebook: Temperature monitor: actual=50.8 C target=60.0 C
# 2026-03-30 15:09:28,897 INFO bioshake-notebook: Temperature monitor: actual=50.8 C target=60.0 C
# 2026-03-30 15:09:29,432 INFO bioshake-notebook: Temperature monitor: actual=50.7 C target=60.0 C
# 2026-03-30 15:09:29,975 INFO bioshake-notebook: Temperature monitor: actual=50.7 C target=60.0 C
# 2026-03-30 15:09:30,518 INFO bioshake-notebook: Temperature monitor: actual=50.7 C target=60.0 C
# 2026-03-30 15:09:31,062 INFO bioshake-notebook: Temperature monitor: actual=50.6 C target=60.0 C
# 2026-03-30 15:09:31,605 INFO bioshake-notebook: Temperature monitor: actual=50.6 C target=60.0 C
# 2026-03-30 15:09:32,148 INFO bioshake-notebook: Temperature monitor: actual=50.6 C target=60.0 C
# 2026-03-30 15:09:32,691 INFO bioshake-notebook: Temperature monitor: actual=50.6 C target=60.0 C
# 2026-03-30 15:09:33,235 INFO bioshake-notebook: Temperature monitor: actual=50.5 C target=60.0 C
# 2026-03-30 15:09:33,778 INFO bioshake-notebook: Temperature monitor: actual=50.5 C target=60.0 C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 12
#       8         "Temperature monitor: actual=%.1f C target=%.1f C",
#       9         actual_temp,
#      10         TARGET_TEMP_C,
#      11     )
# ---> 12     time.sleep(0.5)
#
# KeyboardInterrupt:

# %%
logger.info("Closing ELM")
if not bioshake.close_clamp():
    raise RuntimeError("Failed to close the clamp")
# Out:
# 2026-03-30 15:10:34,432 INFO bioshake-notebook: Closing ELM
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 3
#       1 logger.info("Closing ELM")
#       2 if not bioshake.close_clamp():
# ----> 3     raise RuntimeError("Failed to close the clamp")
#
# RuntimeError: Failed to close the clamp

# %%
logger.info("Opening ELM")
if not bioshake.open_clamp():
    raise RuntimeError("Failed to open the clamp")
# Out:
# 2026-03-30 15:10:31,248 INFO bioshake-notebook: Opening ELM

# %%
bioshake.disconnect()
logger.info("Disconnected from shaker")
